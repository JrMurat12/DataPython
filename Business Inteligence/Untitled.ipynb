# %%
import pandas as pd
import statsmodels.api as sm

# %%
dados = pd.read_csv("HBAT.csv")
dados
# Out:
#     Unnamed: 0   id                x1                  x2                x3  \
# 0            1    1      1 to 5 years   Magazine industry      Large (500+)
# 1            2    2      Over 5 years  Newsprint industry  Small (0 to 499)
# 2            3    3      Over 5 years   Magazine industry      Large (500+)
# 3            4    4  Less than 1 year  Newsprint industry      Large (500+)
# 4            5    5      1 to 5 years   Magazine industry      Large (500+)
# ..         ...  ...               ...                 ...               ...
# 95          96   96  Less than 1 year  Newsprint industry  Small (0 to 499)
# 96          97   97  Less than 1 year   Magazine industry  Small (0 to 499)
# 97          98   98  Less than 1 year   Magazine industry  Small (0 to 499)
# 98          99   99      1 to 5 years  Newsprint industry  Small (0 to 499)
# 99         100  100      1 to 5 years  Newsprint industry      Large (500+)
#
# ...
