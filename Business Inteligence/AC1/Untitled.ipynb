# %%
import pandas as pd
import statsmodels.api as sm

# %%
#GRUPO 
#ALUNO: JEFFERSON P. MURAT JUNIOR RA: 200761
#ALUNO: PABLO MIGUEL RA: 211446
#ALUNO: FELIPE LUCAS DE LIMA SILVA RA: 211588


#VARIAVEIS
#ULTIMA CONSULTA NO ARQUIVO


#EQUAÇÃO DA RETA
#CNT = 1015,8552 + 512,2856*SEASON + 2068,5038*YR + (-44,9537)*MNTH + (-594,4126)*HOLIDAY + 75,6643*WEEKDAY + (-767,7424)*WEATHERSIT + 5725,7244*ATEMP + (-2034,3002)*WINDSPEED

# %%
dados = pd.read_excel("bike-rental_day.xlsx")
dados
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
dados.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
#ADD INSTANT

# %%
X = dados[['instant']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.395
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     476.8
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):           1.02e-81
# Time:                        21:30:52   Log-Likelihood:                -6385.8
# No. Observations:                 731   AIC:                         1.278e+04
# Df Residuals:                     729   BIC:                         1.278e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2392.9613    111.613     21.440      0.000    2173.839    2612.083
# ...

# %%
#ADD SEASON

# %%
X = dados[['instant', 'season']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     265.1
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):           3.17e-87
# Time:                        21:37:21   Log-Likelihood:                -6369.7
# No. Observations:                 731   AIC:                         1.275e+04
# Df Residuals:                     728   BIC:                         1.276e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1867.4451    142.769     13.080      0.000    1587.156    2147.734
# ...

# %%
#ADD YR

# %%
X = dados[['instant', 'season', 'yr']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     241.1
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.48e-108
# Time:                        21:37:49   Log-Likelihood:                -6317.3
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     727   BIC:                         1.266e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1583.5113    135.663     11.672      0.000    1317.174    1849.849
# ...

# %%
#ADD MNTH

# %%
X = dados[['instant', 'season', 'yr', 'mnth']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     181.0
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.58e-107
# Time:                        21:38:23   Log-Likelihood:                -6316.8
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     726   BIC:                         1.267e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1497.4485    162.780      9.199      0.000    1177.873    1817.024
# ...

# %%
#REMOVE INSTANT

# %%
X = dados[['season', 'yr', 'mnth', 'holiday']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     182.7
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          2.89e-108
# Time:                        22:03:06   Log-Likelihood:                -6315.1
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     726   BIC:                         1.266e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1661.8044    135.196     12.292      0.000    1396.383    1927.225
# ...

# %%
#ADD WEEKDAY

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     148.7
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.45e-108
# Time:                        22:03:43   Log-Likelihood:                -6311.7
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     725   BIC:                         1.266e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1460.0335    155.406      9.395      0.000    1154.933    1765.134
# ...

# %%
#ADD WORKINGDAY

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     124.5
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          6.23e-108
# Time:                        22:04:31   Log-Likelihood:                -6310.6
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     724   BIC:                         1.267e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1345.4462    173.354      7.761      0.000    1005.110    1685.782
# ...

# %%
#REMOVE WORKINGDAY

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday',]]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     148.7
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.45e-108
# Time:                        22:08:51   Log-Likelihood:                -6311.7
# No. Observations:                 731   AIC:                         1.264e+04
# Df Residuals:                     725   BIC:                         1.266e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1460.0335    155.406      9.395      0.000    1154.933    1765.134
# ...

# %%
#ADD WEATHERSIT

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.580
# Method:                 Least Squares   F-statistic:                     168.9
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          5.35e-134
# Time:                        22:09:56   Log-Likelihood:                -6249.7
# No. Observations:                 731   AIC:                         1.251e+04
# Df Residuals:                     724   BIC:                         1.255e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2825.9199    185.344     15.247      0.000    2462.045    3189.795
# ...

# %%
#ADD TEMP

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     382.0
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          5.23e-238
# Time:                        22:11:08   Log-Likelihood:                -6004.2
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     723   BIC:                         1.206e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        733.4851    154.579      4.745      0.000     430.008    1036.963
# ...

# %%
#ADD ATEMP

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                     338.8
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.45e-238
# Time:                        22:13:02   Log-Likelihood:                -5999.8
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     722   BIC:                         1.206e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        557.1049    165.050      3.375      0.001     233.070     881.139
# ...

# %%
#ADD HUM

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     302.5
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          5.52e-238
# Time:                        22:14:16   Log-Likelihood:                -5998.2
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     721   BIC:                         1.206e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        724.5578    189.259      3.828      0.000     352.993    1096.123
# ...

# %%
#REMOVE HUM

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                     338.8
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          1.45e-238
# Time:                        22:18:49   Log-Likelihood:                -5999.8
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     722   BIC:                         1.206e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        557.1049    165.050      3.375      0.001     233.070     881.139
# ...

# %%
#REMOVE ATEMP

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     382.0
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          5.23e-238
# Time:                        22:20:45   Log-Likelihood:                -6004.2
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     723   BIC:                         1.206e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        733.4851    154.579      4.745      0.000     430.008    1036.963
# ...

# %%
#ADD HUM

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp', 'hum']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     334.9
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          4.14e-237
# Time:                        22:21:10   Log-Likelihood:                -6003.2
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     722   BIC:                         1.207e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        872.2110    184.550      4.726      0.000     509.892    1234.530
# ...

# %%
#REMOVE HUM

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     382.0
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          5.23e-238
# Time:                        22:21:51   Log-Likelihood:                -6004.2
# No. Observations:                 731   AIC:                         1.202e+04
# Df Residuals:                     723   BIC:                         1.206e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        733.4851    154.579      4.745      0.000     430.008    1036.963
# ...

# %%
#ADD WINDSPEED

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'temp', 'windspeed']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.793
# Method:                 Least Squares   F-statistic:                     350.8
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          7.27e-243
# Time:                        22:22:24   Log-Likelihood:                -5989.8
# No. Observations:                 731   AIC:                         1.200e+04
# Df Residuals:                     722   BIC:                         1.204e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1287.1707    183.218      7.025      0.000     927.466    1646.875
# ...

# %%
#CHANGE TEMP FOR ATEMP

# %%
X = dados[['season', 'yr', 'mnth', 'holiday', 'weekday', 'weathersit', 'atemp', 'windspeed']]
y = dados ['cnt']

X = sm.add_constant (X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.793
# Method:                 Least Squares   F-statistic:                     351.5
# Date:                Fri, 16 Sep 2022   Prob (F-statistic):          4.22e-243
# Time:                        22:23:42   Log-Likelihood:                -5989.2
# No. Observations:                 731   AIC:                         1.200e+04
# Df Residuals:                     722   BIC:                         1.204e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1015.8552    188.147      5.399      0.000     646.474    1385.236
# ...

# %%
#CNT = 1015,8552 + 512,2856*SEASON + 2068,5038*YR + (-44,9537)*MNTH + (-594,4126)*HOLIDAY + 75,6643*WEEKDAY + (-767,7424)*WEATHERSIT + 5725,7244*ATEMP + (-2034,3002)*WINDSPEED
